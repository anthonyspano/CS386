# %%
#1. Pickle
from google.colab import drive
drive.mount('/content/drive')
# mount '/content/drive' to virtual machine directory for google colab user
#below where the file is in gdrive, change with your
data_path = "/content/drive/My Drive/Colab Notebooks/Lab7/"

import pickle

dogs_dict = { 'Ozzy': 3, 'Filou': 8, 'Luna': 5, 'Skippy': 10, 'Barco': 12, 'Balou': 9, 'Laika': 16 }
filename = 'dogs'
outfile = open(data_path+filename,'wb') # b: binary
pickle.dump(dogs_dict,outfile)
outfile.close() # File "dogs" will be created in your google drive
infile = open(data_path+filename,'rb')
new_dict = pickle.load(infile)
infile.close()
print(new_dict)
print(new_dict==dogs_dict)
print(type(new_dict))

import bz2 # Compressing pickle files
sfile = bz2.BZ2File(data_path+'smallerfile', 'w')
pickle.dump(dogs_dict, sfile) # zipped file "smallerfile" will be in your google drive
infile = open(data_path+filename,'rb')
new_dict = pickle.load(infile, encoding='latin1')

#2. Get dataset from website
# !pip install quandl
import quandl
import pandas as pd
# Access to https://www.quandl.com/
# Create account and then you will get your own api key
# DON'T USE MY API KEY
api_key = 'NhANVVSodU-9xntqjo4F'
df = quandl.get("FMAC/HPI_TX", authtoken=api_key)
print(df.head())
fiddy_states = pd.read_html('https://simple.wikipedia.org/wiki/List_of_U.S._states')
#print(fiddy_states)
#print(fiddy_states[0])

# Exercise 2
# could not find weather data set available - using mitosis data set from earlier hw
data_path = "/content/drive/My Drive/Colab Notebooks/"
filename = "mitosis.csv"
readfile = open(data_path+filename, 'r')
for line in readfile:
  print(line)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# {'Ozzy': 3, 'Filou': 8, 'Luna': 5, 'Skippy': 10, 'Barco': 12, 'Balou': 9, 'Laika': 16}
# True
# <class 'dict'>
# Requirement already satisfied: quandl in /usr/local/lib/python3.6/dist-packages (3.5.0)
# Requirement already satisfied: inflection>=0.3.1 in /usr/local/lib/python3.6/dist-packages (from quandl) (0.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from quandl) (1.12.0)
# Requirement already satisfied: numpy>=1.8 in /usr/local/lib/python3.6/dist-packages (from quandl) (1.18.5)
# Requirement already satisfied: pandas>=0.14 in /usr/local/lib/python3.6/dist-packages (from quandl) (1.0.5)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from quandl) (2.8.1)
# Requirement already satisfied: requests>=2.7.0 in /usr/local/lib/python3.6/dist-packages (from quandl) (2.23.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.6/dist-packages (from quandl) (8.4.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.14->quandl) (2018.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.7.0->quandl) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.7.0->quandl) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.7.0->quandl) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.7.0->quandl) (2.9)
#             NSA Value   SA Value
# Date
# 1975-01-31  32.836319  32.820449
# 1975-02-28  33.065193  33.042385
# 1975-03-31  33.576467  33.460595
# 1975-04-30  34.366551  34.204250
# 1975-05-31  34.559775  34.335558
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,y
#
# 1,8,10,10,8,7,10,9,7,1,0
#
# 1,5,3,3,3,2,3,4,4,1,0
#
# 1,1,1,1,1,2,3,3,1,1,1
#
# 1,8,7,5,10,7,9,5,5,4,0
#
# 1,7,4,6,4,6,1,4,3,1,0
#
# 1,4,1,1,1,2,1,2,1,1,1
#
# 1,4,1,1,1,2,1,3,1,1,1
#
# 1,10,7,7,6,4,10,4,1,2,0
#
# 1,6,1,1,1,2,1,3,1,1,1
#
# 1,7,3,2,10,5,10,5,4,4,0
#
# 1,10,5,5,3,6,7,7,10,1,0
#
# 1,3,1,1,1,2,1,2,1,1,1
#
# 1,8,4,5,1,2,5,7,3,1,0
#
# 1,1,1,1,1,2,1,3,1,1,1
#
# 1,5,2,3,4,2,7,3,6,1,0
#
# 1,3,2,1,1,1,1,2,1,1,1
#
# 1,5,1,1,1,2,1,2,1,1,0
#
# 1,2,1,1,1,2,1,2,1,1,1
#
# 1,1,1,3,1,2,1,1,1,1,1
#
# 1,3,1,1,1,1,1,2,1,1,1
#
# 1,2,1,1,1,2,1,3,1,1,1
#
# 1,10,7,7,3,8,5,7,4,3,0
#
# 1,2,1,1,2,2,1,3,1,1,1
#
# 1,3,1,2,1,2,1,2,1,1,1
#
# 1,2,1,1,1,2,1,2,1,1,1
#
# 1,10,10,10,8,6,1,8,9,1,0
#
# 1,6,2,1,1,1,1,7,1,1,1
#
# 1,5,4,4,9,2,10,5,6,1,0
#
# 1,2,5,3,3,6,7,7,5,1,0
#
# 1,10,4,3,1,3,3,6,5,2,0
#
# 1,6,10,10,2,8,10,7,3,3,0
#
# 1,5,6,5,6,10,1,3,1,1,0
